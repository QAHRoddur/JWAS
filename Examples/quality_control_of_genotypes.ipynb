# %% [markdown]
# # Quality Control of Genotypes
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/QAHRoddur/JWAS/blob/main/Examples/quality_control_of_genotypes.ipynb)
#
# This notebook is auto-generated from the JWAS.jl wiki page.

# %%
using Pkg
Pkg.add("JWAS")
Pkg.precompile()
using JWAS

# %%
# One-time setup each Colab session
if !isdir("/content/JWAS")
    run(`git clone https://github.com/QAHRoddur/JWAS.git /content/JWAS`)
end
cd("/content/JWAS/Examples")
pwd()  # should show /content/JWAS/Examples

# %% [markdown]
# Simple quality control is available for genotypes. In `get_genotypes` function, when `quality_control`=true, minor allele frequency `MAF` threshold, defaulting to **0.01**, is used, and fixed loci are removed. In addition, missing genotypes will be replaced by column means if they are denoted as `9` . Users can also impute missing genotypes before the analysis.

# %%
using JWAS,JWAS.Datasets
genofile   = "../data/genotypes.txt"
genotypes  = get_genotypes(genofile, separator=',', quality_control=true, MAF=0.05);
