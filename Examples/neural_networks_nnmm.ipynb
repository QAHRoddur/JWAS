# %% [markdown]
# # Neural Networks (NNMM)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/QAHRoddur/JWAS/blob/main/Examples/neural_networks_nnmm.ipynb)
#
# This notebook is auto-generated from the JWAS.jl wiki page.

# %%
using Pkg
Pkg.add("JWAS")
Pkg.precompile()
using JWAS

# %%
# One-time setup each Colab session
if !isdir("/content/JWAS")
    run(`git clone https://github.com/QAHRoddur/JWAS.git /content/JWAS`)
end
cd("/content/JWAS/Examples")
pwd()  # should show /content/JWAS/Examples

# %% [markdown]
# # Neural Networks (NN-LMM) — Moved to NNMM.jl
#
# > **The NN-LMM functionality has been moved to a separate package: [NNMM.jl](https://github.com/reworkhow/NNMM.jl)**
# >
# > Please refer to the NNMM.jl repository for documentation, examples, and installation instructions.
#
# ## References
#
# > * Tianjing Zhao, Jian Zeng, and Hao Cheng. Extend Mixed Models to Multi-layer Neural Networks for Genomic Prediction Including Intermediate Omics Data, bioRxiv 2021.12.10.472186; https://doi.org/10.1101/2021.12.10.472186.
# > * Tianjing Zhao, Rohan Fernando, and Hao Cheng. Interpretable artificial neural networks incorporating Bayesian alphabet models for genome-wide prediction and association studies, G3 Genes|Genomes|Genetics, 2021; jkab228, https://doi.org/10.1093/g3journal/jkab228
