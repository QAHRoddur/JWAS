# %% [markdown]
# # Frequently Asked Questions
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/QAHRoddur/JWAS/blob/main/FAQ/frequently_asked_questions.ipynb)
#
# This notebook is auto-generated from the JWAS.jl wiki page.

# %%
using Pkg
Pkg.add("JWAS")
Pkg.precompile()
using JWAS

# %% [markdown]
# * About **Julia**
#   * How do I save variables in Julia and load those again for another analysis (similar to  .RData files in R to store objects)?
#     * JLD.jl is flexible to save arbitrary Julia variables.
#       * using JLD; save("/tmp/myfile.jld", "model", model, "ped", pedigree)
#     * Feather
#       * R
# * About **Bayesian Methods**
#   * Does thinning matter?
#     * [Thinning to reduce autocorrelation: Rarely useful!](http://doingbayesiandataanalysis.blogspot.com/2011/11/thinning-to-reduce-autocorrelation.html)
#     * The default value for output_samples_frequency (thinning) is `chain_length/1000` to save MCMC samples every **output_samples_frequency** iterations to files **output_samples_file** and use these samples to compute posterior mean and variance. This value is used mainly for computational reason since saving MCMC samples too frequently slows down the computation.
#   * How do we deal with missing records?
#     * missing phenotypes
#     * missing independent variables
# * About errors when running Julia or JWAS
#   * Error: "Can’t install XXX.jl - unsatisfiable requirements detected"...- “restricted to versions 1.0.0 by an explicit requirement”
#     * > The explanation ([as I understand it](https://discourse.julialang.org/t/cant-install-gadfly-unsatisfiable-requirements-detected/22205/12)) is that if you have a package B (e.g. StatsBase) installed independently in your (REPL) environment that package A (e.g. Gadfly) depends on, then package B in your (REPL) environment needs to match package A’s Project.toml
#     * run `using Pkg; Pkg.update()` to solve this problem
